# %% [markdown]
# # 01 — Ingest: MSSQL → Bronze Parquet
#
# Reads tables from SQL Server and writes them as Parquet in the **bronze** zone.

# %%
import sys, os
sys.path.insert(0, '/workspace')

from scripts.spark_session import get_spark, JDBC_URL, JDBC_PROPS, BRONZE

spark = get_spark('01_ingest')
print(f'Spark version: {spark.version}')
# Out:
# 26/03/20 05:58:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/20 05:58:25 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Spark version: 3.5.1

# %%
df_customers = spark.read.jdbc(JDBC_URL, 'dbo.customers', properties=JDBC_PROPS)
df_customers.show()
df_customers.write.mode('overwrite').parquet(f'{BRONZE}/customers')
print(f'✅ Wrote {df_customers.count()} customers to bronze')
# Out:
# +-----------+-----------------+------+-----------+
# |customer_id|             name|region|signup_date|
# +-----------+-----------------+------+-----------+
# |          1|      Contoso Ltd|  West| 2023-01-15|
# |          2|Northwind Traders|  East| 2023-03-22|
# |          3|  Adventure Works|  West| 2023-06-10|
# |          4|     Fabrikam Inc| South| 2023-07-01|
# |          5|    Tailspin Toys|  East| 2023-09-18|
# +-----------+-----------------+------+-----------+
# ✅ Wrote 5 customers to bronze

# %%
df_orders = spark.read.jdbc(JDBC_URL, 'dbo.orders', properties=JDBC_PROPS)
df_orders.show()
df_orders.write.mode('overwrite').parquet(f'{BRONZE}/orders')
print(f'✅ Wrote {df_orders.count()} orders to bronze')
# Out:
# +--------+-----------+----------+--------+--------+----------+
# |order_id|customer_id|order_date| product|quantity|unit_price|
# +--------+-----------+----------+--------+--------+----------+
# |     101|          1|2024-01-05|Widget A|      10|     29.99|
# |     102|          1|2024-01-20|Widget B|       5|     49.99|
# |     103|          2|2024-02-11|Widget A|      20|     29.99|
# |     104|          3|2024-02-15|Gadget X|       2|    199.99|
# |     105|          2|2024-03-01|Widget C|      15|     39.99|
# |     106|          4|2024-03-10|Gadget X|       1|    199.99|
# |     107|          5|2024-03-22|Widget A|      30|     29.99|
# |     108|          3|2024-04-05|Widget B|       8|     49.99|
# |     109|          1|2024-04-18|Gadget Y|       3|    149.99|
# |     110|          4|2024-05-02|Widget C|      12|     39.99|
# +--------+-----------+----------+--------+--------+----------+
#
# ✅ Wrote 10 orders to bronze
